# %%
! git clone https://github.com/borisdayma/lightning-kitti.git
# Out:
# Cloning into 'lightning-kitti'...
# remote: Enumerating objects: 83, done.
# remote: Counting objects: 100% (83/83), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 83 (delta 38), reused 70 (delta 25), pack-reused 0
# Unpacking objects: 100% (83/83), done.

# %%
! wget https://s3.eu-central-1.amazonaws.com/avg-kitti/data_semantics.zip
# Out:
# --2020-12-23 17:05:13--  https://s3.eu-central-1.amazonaws.com/avg-kitti/data_semantics.zip
# Resolving s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)... 52.219.47.111
# Connecting to s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)|52.219.47.111|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 327699796 (313M) [application/zip]
# Saving to: ‘data_semantics.zip’
#
# data_semantics.zip  100%[===================>] 312.52M  33.4MB/s    in 10s
#
# 2020-12-23 17:05:23 (31.2 MB/s) - ‘data_semantics.zip’ saved [327699796/327699796]

# %%
! unzip /content/data_semantics.zip -d /content/lightning-kitti/data_semantics

# %%
# %cd /content/lightning-kitti/
# Out:
# /content/lightning-kitti

# %%
! pip install --upgrade future
! pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 829kB 10.3MB/s
# ...
#   Created wheel for future: filename=future-0.18.2-cp36-none-any.whl size=491057 sha256=5cdc32a5cbaaf02731231790bdd3e81ba7ea2441feb9ca03fb4a3d0c88f61304
#   Stored in directory: /root/.cache/pip/wheels/8b/99/a0/81daf51dcd359a9377b110a8a886b3895921802d2fc1b2397e
# Successfully built future
# ...
#   Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
# ...
#      |████████████████████████████████| 675kB 14.9MB/s
# ...
#      |████████████████████████████████| 1.8MB 19.7MB/s
# ...
#      |████████████████████████████████| 276kB 58.6MB/s
# ...
#      |████████████████████████████████| 102kB 15.6MB/s
# ...
#      |████████████████████████████████| 81kB 13.1MB/s
# ...
#      |████████████████████████████████| 102kB 16.1MB/s
# ...
#      |████████████████████████████████| 133kB 61.8MB/s
# ...
#      |████████████████████████████████| 163kB 63.2MB/s
# ...
#      |████████████████████████████████| 71kB 12.9MB/s
# ...

# %%
! python train.py
# Out:
# wandb: Currently logged in as: repro (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.10.12
# wandb: Syncing run clean-galaxy-3
# wandb: ⭐️ View project at https://wandb.ai/repro/lightning-kitti
# wandb: 🚀 View run at https://wandb.ai/repro/lightning-kitti/runs/355wdn78
# wandb: Run data is saved locally in /content/lightning-kitti/wandb/run-20201223_171011-355wdn78
# wandb: Run `wandb offline` to turn off syncing.
#
# Starting a run with {'data_path': 'data_semantics', 'batch_size': 2, 'lr': 0.001, 'num_layers': 5, 'features_start': 64, 'bilinear': False, 'grad_batches': 1, 'epochs': 20}
# {'data_path': 'data_semantics', 'batch_size': 2, 'lr': 0.001, 'num_layers': 5, 'features_start': 64, 'bilinear': False, 'grad_batches': 1, 'epochs': 20}
# ...

# %%
! wandb sweep sweep.yaml
# Out:
# wandb: Creating sweep from: sweep.yaml
# wandb: Created sweep with ID: i2v70ocv
# wandb: View sweep at: https://wandb.ai/repro/lightning-kitti/sweeps/i2v70ocv
# wandb: Run sweep agent with: wandb agent repro/lightning-kitti/i2v70ocv

# %%
! wandb agent repro/lightning-kitti/i2v70ocv
# Out:
# wandb: Starting wandb agent 🕵️
# 2020-12-23 17:42:03,397 - wandb.wandb_agent - INFO - Running runs: []
# 2020-12-23 17:42:03,574 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-12-23 17:42:03,574 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	batch_size: 3
# 	bilinear: True
# 	features_start: 16
# 	grad_batches: 6
# 	lr: 0.00017764554205722434
# 	num_layers: 2
# 2020-12-23 17:42:03,576 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --batch_size=3 --bilinear=True --features_start=16 --grad_batches=6 --lr=0.00017764554205722434 --num_layers=2
# wandb: Currently logged in as: repro (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.10.12
# wandb: Syncing run bright-sweep-1
# wandb: ⭐️ View project at https://wandb.ai/repro/lightning-kitti
# wandb: 🧹 View sweep at https://wandb.ai/repro/lightning-kitti/sweeps/i2v70ocv
# ...
